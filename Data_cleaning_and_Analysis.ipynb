# %% [markdown]
# <a href="https://colab.research.google.com/github/tuleshthosare28-ux/CodeOrbit-Data-Analyst-Intership./blob/main/Data_cleaning_and_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
csv_data = """OrderID,Date,CustomerName,Product,Category,Region,Quantity,Price,TotalSales
1001,2026-01-01,Alice,Laptop,Electronics,North,1,1200,1200
1002,2026-01-02,Bob,Shirt,Clothing,West,2,25,50
1003,,Charlie,Laptop,Electronics,East,1,1200,1200
1004,2026-01-03,Alice,Shoes,Clothing,North,,50,0
1002,2026-01-02,Bob,Shirt,Clothing,West,2,25,50
1005,2026-01-04,David,Headphones,electronics,South,3,100,300
1006,2026-01-05,Eva,Laptop,Electronics,West,1,,1200
1007,2026-01-06,Frank,Jeans,Clothing,East,2,60,120
1008,2026-01-06,Grace,TV,Electronics,North,1,800,800
1009,2026-01-07,Henry,Socks,Clothing,West,5,10,50
1010,2026-01-08,Ivy,Backpack,Home & Kitchen,East,1,45,45
1011,2026-01-09,Jack,Blender,Home & Kitchen,South,1,150,150
1012,,Kevin,Shirt,Clothing,North,3,25,75
1013,2026-01-11,Leo,Laptop,Electronics,West,1,1200,1200
1014,2026-01-12,Mia,Shoes,Clothing,East,,50,100
1015,2026-01-13,Noah,Headphones,electronics,South,2,100,200
1016,2026-01-14,Olivia,Jeans,Clothing,North,1,60,60
1017,2026-01-15,Peter,TV,Electronics,West,1,800,800
1018,2026-01-16,Quinn,Socks,clothing,East,10,10,100
1019,2026-01-17,Rachel,Backpack,Home & Kitchen,South,2,45,90
1020,2026-01-18,Sam,Blender,Home & Kitchen,North,1,,150
1021,2026-01-19,Tom,Shirt,Clothing,West,4,25,100
1022,2026-01-20,Ursula,Laptop,Electronics,East,1,1200,1200
1023,2026-01-21,Victor,Shoes,Clothing,South,1,50,50
1024,2026-01-22,Wendy,Headphones,Electronics,North,2,100,200
1025,2026-01-23,Xavier,Jeans,Clothing,West,2,60,120
1024,2026-01-22,Wendy,Headphones,Electronics,North,2,100,200
1026,2026-01-24,Yara,TV,electronics,East,1,800,800
1027,2026-01-25,Zane,Socks,Clothing,South,3,10,30
1028,,Alice,Backpack,Home & Kitchen,North,1,45,45
1029,2026-01-27,Bob,Blender,Home & Kitchen,West,2,150,300
1030,2026-01-28,Charlie,Shirt,Clothing,East,2,25,50
1031,2026-01-29,David,Laptop,Electronics,South,1,1200,1200
1032,2026-01-30,Eva,Shoes,Clothing,North,3,50,150
1033,2026-01-31,Frank,Headphones,Electronics,West,1,100,100
1034,2026-02-01,Grace,Jeans,Clothing,East,1,60,60
1035,2026-02-02,Henry,TV,Electronics,South,2,800,1600
1036,2026-02-03,Ivy,Socks,Clothing,North,6,10,60
1037,2026-02-04,Jack,Backpack,Home & Kitchen,West,1,45,45
1038,,Kevin,Blender,Home & Kitchen,East,1,150,150
1039,2026-02-06,Leo,Shirt,Clothing,South,2,25,50
1040,2026-02-07,Mia,Laptop,Electronics,North,1,1200,1200
1041,2026-02-08,Noah,Shoes,clothing,West,,50,250
1042,2026-02-09,Olivia,Headphones,Electronics,East,1,100,100
1043,2026-02-10,Peter,Jeans,Clothing,South,3,60,180
1044,2026-02-11,Quinn,TV,Electronics,North,1,800,800
1045,2026-02-12,Rachel,Socks,Clothing,West,8,10,80
1046,2026-02-13,Sam,Backpack,Home & Kitchen,East,2,45,90
1047,2026-02-14,Tom,Blender,Home & Kitchen,South,1,,150
1048,2026-02-15,Ursula,Shirt,Clothing,North,2,25,50
1049,2026-02-16,Victor,Laptop,electronics,West,1,1200,1200
1050,2026-02-17,Wendy,Shoes,Clothing,East,1,50,50
1049,2026-02-16,Victor,Laptop,electronics,West,1,1200,1200
1051,2026-02-18,Xavier,Headphones,Electronics,South,2,100,200
1052,2026-02-19,Yara,Jeans,Clothing,North,1,60,60
1053,2026-02-20,Zane,TV,Electronics,West,1,800,800
1054,,Alice,Socks,Clothing,East,4,10,40
1055,2026-02-22,Bob,Backpack,Home & Kitchen,South,1,45,45
1056,2026-02-23,Charlie,Blender,Home & Kitchen,North,2,150,300
1057,2026-02-24,David,Shirt,Clothing,West,3,25,75"""

with open('raw_sales_data.csv', 'w') as f:
    f.write(csv_data)

import pandas as pd

# Prevent wrapping to new lines
pd.set_option('display.expand_frame_repr', False)

# Optional: Ensure all columns are shown if you have a lot of them
pd.set_option('display.max_columns', None)

# Now print your data
print()

# 1. Load the dirty dataset
df = pd.read_csv('raw_sales_data.csv')
print("--- Raw Data ---")
print(df)
print("\n" + "="*50 + "\n")

# 2. Handle Duplicates
# This removes the duplicate row for OrderID 1002
df = df.drop_duplicates()

# 3. Handle Formatting Issues (Capitalization)
# Changes "electronics" to "Electronics" so grouping works correctly later
df['Category'] = df['Category'].str.capitalize()

# 4. Handle Missing Values
# Fill missing dates with a placeholder or forward fill
df['Date'] = df['Date'].ffill()

# Fill missing quantities with 1 (a safe logical assumption for a purchase)
df['Quantity'] = df['Quantity'].fillna(1)

# Recalculate 'TotalSales' where it is 0 or incorrect (Quantity * Price)
# For OrderID 1006, Price is missing, so let's drop rows where Price is unknown
df = df.dropna(subset=['Price'])

# Ensure TotalSales perfectly matches Quantity * Price
df['TotalSales'] = df['Quantity'] * df['Price']

# 5. Review and Save the Cleaned Dataset
print("--- Cleaned Data ---")
print(df)

# Export to a new CSV file for your dashboard and SQL tasks
df.to_csv('clean_sales_data.csv', index=False)
print("\nSuccess! 'clean_sales_data.csv' has been created.")
# Out:
# --- Raw Data ---
#     OrderID        Date CustomerName     Product        Category Region  Quantity   Price  TotalSales
# 0      1001  2026-01-01        Alice      Laptop     Electronics  North       1.0  1200.0        1200
# 1      1002  2026-01-02          Bob       Shirt        Clothing   West       2.0    25.0          50
# 47     1046  2026-02-13          Sam    Backpack  Home & kitchen   East       2.0    45.0        90.0
# 49     1048  2026-02-15       Ursula       Shirt        Clothing  North       2.0    25.0        50.0
# 50     1049  2026-02-16       Victor      Laptop     Electronics   West       1.0  1200.0      1200.0
# 51     1050  2026-02-17        Wendy       Shoes        Clothing   East       1.0    50.0        50.0
# 53     1051  2026-02-18       Xavier  Headphones     Electronics  South       2.0   100.0       200.0
# 54     1052  2026-02-19         Yara       Jeans        Clothing  North       1.0    60.0        60.0
# 55     1053  2026-02-20         Zane          TV     Electronics   West       1.0   800.0       800.0
# 56     1054  2026-02-20        Alice       Socks        Clothing   East       4.0    10.0        40.0
# 57     1055  2026-02-22          Bob    Backpack  Home & kitchen  South       1.0    45.0        45.0
# 58     1056  2026-02-23      Charlie     Blender  Home & kitchen  North       2.0   150.0       300.0
# 59     1057  2026-02-24        David       Shirt        Clothing   West       3.0    25.0        75.0
#
# Success! 'clean_sales_data.csv' has been created.

# %%
import pandas as pd

# --- TASK 2: SALES DATA ANALYSIS ---

# Load the cleaned dataset
df = pd.read_csv('clean_sales_data.csv')

print("--- TASK 2: KEY BUSINESS METRICS ---")

# 1. Calculate Total Overall Sales
total_sales = df['TotalSales'].sum()
print(f"Total Revenue Generated: ${total_sales:,.2f}")

# 2. Calculate Average Order Value (AOV)
average_order_value = df['TotalSales'].mean()
print(f"Average Order Value: ${average_order_value:,.2f}")

# 3. Identify Top Performing Products (Sorted by quantity sold)
top_products = df.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
print("\nTop Selling Products (by Quantity):")
print(top_products)

print("\n" + "="*50 + "\n")
print("--- TASK 2: DATA GROUPING & SUMMARIZATION ---")

# 4. Group and summarize Total Sales by Region
sales_by_region = df.groupby('Region')['TotalSales'].sum().sort_values(ascending=False)
print("Total Sales by Region:")
print(sales_by_region.map('${:,.2f}'.format))

# 5. Group and summarize Total Sales by Product Category
sales_by_category = df.groupby('Category')['TotalSales'].sum().sort_values(ascending=False)
print("\nTotal Sales by Category:")
print(sales_by_category.map('${:,.2f}'.format))
# Out:
# --- TASK 2: KEY BUSINESS METRICS ---
# Total Revenue Generated: $18,170.00
# Average Order Value: $336.48
#
# Top Selling Products (by Quantity):
# Product
# Socks         36.0
# Shirt         18.0
# Headphones    11.0
# Jeans         10.0
# Backpack       8.0
# Shoes          8.0
# Laptop         7.0
# TV             7.0
# Blender        6.0
# Name: Quantity, dtype: float64
#
# ==================================================
#
# --- TASK 2: DATA GROUPING & SUMMARIZATION ---
# Total Sales by Region:
# Region
# North    $5,050.00
# West     $4,970.00
# South    $4,095.00
# East     $4,055.00
# Name: TotalSales, dtype: object
#
# Total Sales by Category:
# Category
# Electronics       $15,100.00
# Clothing           $1,810.00
# Home & kitchen     $1,260.00
# Name: TotalSales, dtype: object
